% %% [markdown]
% <font size = '6'><b>Discrete Fourier Transformation (DFT)</b></font>
%
% <table style="border-style: hidden; border-collapse: collapse;" width = "96%">
%     <tr style="border-style: hidden; border-collapse: collapse;">
%         <td width = 70% style="border-style: hidden; border-collapse: collapse;">
%
%         </td>
%         <td width = 16%>
%             Prof. Seungchul Lee
%
%             [http://isystems.unist.ac.kr/](http://isystems.unist.ac.kr/)
%             UNIST
%         </td>
%     </tr>
% </table>
%
%
% Table of Contents
% <div id="toc"></div>

% %% [markdown]
% # Fourier Series

% %% [markdown]
% ## Delta Dirac Function

% %%
%plot -s 800,200
theta = linspace(0,6*pi,2^8);
x1 = cos(theta);
plot(theta,x1)

% %%
%plot -s 800,200
x2 = x1 + cos(2*theta);
plot(theta, x2/2)

% %%
%plot -s 800,200
x = zeros(1,2^8);

for i = 1:30
    x = x + cos(i*theta);
end
plot(theta,x/30)

% %% [markdown]
% ## Square Wave
%
% $$ \sum_{n = 1,3,5,\cdots}\frac{4}{\pi n} sin(nx) $$

% %%
%plot -s 800,300
N = 2^8;
x = zeros(1,N);
theta = linspace(0,2*pi,N);

for n = 1:2:20
    x = x + 4/(pi*n)*sin(n*theta);
end

plot(theta/pi,x), xlabel('\theta in unit \pi')

% %%
%plot -s 800,300
X = dft(x,N)/N;
stem(0:N-1,abs(X)), axis tight, xlabel('k')

% %%
%plot -s 800,300
stem(0:N-1,abs(X)), xlabel('k')
xlim([0,20])

% %%
% sound

N = 2^10;
x = zeros(1,N);
theta = linspace(0,2*pi,N);

for n = 1:2:30
    x = x + 4/(pi*n)*sin(n*theta);
end

x_rep = repmat(x,1,100);
Fs = 44100;

sound(x_rep,Fs);

% %% [markdown]
% ## Sawtooth wave
%
% $$ \frac{1}{2} - \frac{1}{\pi} \sum_{n=1}^{\infty}\frac{1}{n}sin(\pi x)  $$

% %%
%plot -s 800,300
N = 2^8;
x = zeros(1,N);
theta = linspace(0,2*pi,N);


for n = 1:100
    x = x - 1/(pi*n)*sin(n*theta);
end

plot(theta/pi,x), xlabel('\theta in unit \pi')

% %%
%plot -s 800,300
X = fft(x)/N;

stem(0:N-1,abs(X)), xlabel('k')
xlim([0,20])

% %%
% sound

N = 2^10;
x = zeros(1,N);
theta = linspace(0,2*pi,N);

for n = 1:30
    x = x - 1/(pi*n)*sin(n*theta);
end

x_rep = repmat(2*x,1,50); % make a signal -1 to 1 and repeat (periodic)
Fs = 44100;

sound(x_rep,Fs);

% %% [markdown]
% # EigenAnalysis

% %% [markdown]
% ---
% ## Orthogonal Bases
% Signal Representation by Orthonormal Basis
%
%
% $$ x = B\alpha = \sum_{k=0}^{N-1}\alpha_kb_k $$
% $$ \alpha = B^Hx \qquad \text{or} \qquad \alpha_k = \big<x,b_k\big> $$
%
% > **Synthesis**: Build up the signal $x$ as a linear combination of the basis elements $b_k$ weighted by the weights $\alpha_k$
%
% > **Analysis**: Compute the weights $\alpha_k$ such that the synthesis produces $x$; the weight $\alpha_k$ measures the similarity between $x$ and the basis element $b_k$

% %% [markdown]
% ## Eigenvector and eigenvalues
%
% $$Av=\lambda v$$
%
% $$AV=V\Lambda$$
%
% > - Eigenvectors $v$ are input signals that emerge at the system output unchanged (except for a scaling by the eigenvalue \lambda) and so are somehow "fundamental" to the system
%
% > - Eigenanalysis of LTI Systems (Finite-Length Signals)
%
%
% > - Goal: Calcuate the **eigenvectors** and **eigenvalues** of **H**
%
%
% > - Fact: The eigenvectors of a circulent matrix (LTI system) are the complex **harmonic sinusoids**
%
% > - Fact: The eigenvalue $\lambda \in C$ corresponding to the sinusoid eigenvector $s_k$ is called the frequency response at frequency $k$ since it measures how the system "responds" to $s_k$
%
% $$ \lambda_k = \sum_{n=0}^{N-1}h[n]e^{-j\frac{2\pi}{N}kn} = \big< h,s_k\big> = H_u[k] $$

% %% [markdown]
% ## Eigenvector Matrix of Harmonic Sinusoids
%
% $$ S = \big[s_0 | s_1 | \cdots | s_{N-1} \big]  $$
%
% $$s_k[n]=\frac{1}{\sqrt{N}}e^{j\frac{2\pi}{N}kn}$$
%
% > Stack $N$ normalized harmonic sinusoid $\{s_k\}_{k=0}^{N-1}$ as columns into an $N\times N$ complex orthonormal basis matrix

% %%
%plot -s 900,500

% visualize eigenvector matrix 

N = 16;
n = 0:N-1;
k = 0:N-1;

S = 1/sqrt(N)*exp(1j*2*pi/N).^(n'*k);

subplot(1,2,1), imagesc(n,k,real(S)); colormap('jet'); axis('square');
title('real part')
subplot(1,2,2), imagesc(n,k,imag(S)); colormap('jet'); axis('square');
title('imaginary part')

% %% [markdown]
% ## Eigendecomposition and Diagonalization of an LTI Systems
%
% $$H=S \Lambda S^H$$

% %% [markdown]
% <img src="./image_fileseig_decomposition.png" style="border:1px solid black", width = 800>

% %% [markdown]
% <img src="slide_image/signal_rep.png" style="border:1px solid black", width = 800>

% %% [markdown]
% <img src="slide_image/interpreation.png" style="border:1px solid black", width = 800>

% %% [markdown]
% <img src="slide_image/unnormalized_DFT.png" style="border:1px solid black", width = 800>

% %% [markdown]
% ## Unnormalized DFT

% %%
%% DFT without using the built-in function

x = [2 3 -1 4];
N = length(x);
X = zeros(1,N);

for k = 0:N-1
    for n = 0:N-1
        X(k+1) = X(k+1) + x(n+1)*exp(-1j*2*pi/N*n*k);
    end
end

X
% Out:
% X =
%
%    8.0000 + 0.0000i   3.0000 + 1.0000i  -6.0000 - 0.0000i   3.0000 - 1.0000i

% %%
%plot -s 800,500
% plot a discrete-time signal
xn = 0:N-1;
k = 0:N-1;

subplot(3,1,1), stem(xn,x,'filled'), axis([-0.5,3.5,-1.5,4.5]), ylabel('x[n]')
subplot(3,1,2), stem(k,real(X),'filled'), xlim([-0.5,3.5]), ylabel('Real')
subplot(3,1,3), stem(k,imag(X),'filled'), xlim([-0.5,3.5]), ylabel('Imaginary')

% %% [markdown]
% > FFT algorithms are so commonly employed to compute DFTs that the term 'FFT' is often used to mean 'DFT': DFT refers to a mathematical transformation or function, whereas 'FFT' refers to a specific family of algorithms for computing DFTs.
% > - use fft command to compute dft
% > - fft (computationally efficient)

% %%
%% DFT using FFT
% fft(X) is the discrete Fourier transform (DFT) of vector X.
% get the identical results

fft(x)
% Out:
% ans =
%
%    8.0000 + 0.0000i   3.0000 + 1.0000i  -6.0000 + 0.0000i   3.0000 - 1.0000i

% %% [markdown]
% > - can use dft function defined below, but
% > - computationally expensive

% %%
% see the below dft function
dft(x,4)
% Out:
% ans =
%
%    8.0000 + 0.0000i   3.0000 + 1.0000i  -6.0000 - 0.0000i   3.0000 - 1.0000i

% %%
%plot -s 1000,500

k = 4;                         % index for freqeuncy

N = 8;
n = 0:N-1;                    % sampling period

x = exp(1j*2*pi/N*k*n);           % harmonic complex exponential
X = dft(x,N);


subplot(2,2,[1,3]); plot(real(x),imag(x),'o','MarkerFaceColor','b')
axis equal; ylim([-3 3])
xlabel('Real {x}','Fontsize',8)
ylabel('Im {x}','Fontsize',8)
title(['e^{(j2\pi/N kn)},   k = ',num2str(k)],'Fontsize',8)

subplot(2,2,2); stem(n,abs(X),'filled')
xlabel('k','Fontsize',8)
ylabel('Amplitude','Fontsize',8)
title('Result of FFT','fontsize',8)

subplot(2,2,4), stem(n,real(x),'filled')
xlabel('n'), ylabel('x[n]')
title(['e^{(j2\pi/N kn)},   k = ',num2str(k)],'Fontsize',8)

% %%
%plot -s 800,400

k = 2;                         % index for freqeuncy

N = 8;
n = 0:N-1;                    % sampling period

x = sin(2*pi/N*k*n);           % harmonic complex exponential
X = dft(x,N);

subplot(2,1,1), stem(n,real(x),'filled')
xlabel('n'), ylabel('x[n]')
title(['e^{(j2\pi/N kn)},   k = ',num2str(k)],'Fontsize',8)

subplot(2,1,2); stem(n,abs(X),'filled')
xlabel('k','Fontsize',8)
ylabel('Amplitude','Fontsize',8)
title('Result of FFT','fontsize',8)

% %% [markdown]
% # DFT Properties

% %% [markdown]
% ## DFT pair
%
% $$x[n] \leftrightarrow X[k]$$

% %% [markdown]
% ## DFT Frequencies
%
% $X[k]$ measures the similarity between the time signal $x[n]$ and the harmonic sinusoid $s_k[n]$
%
% $X[k]$ measures the "frequency content" of $x[n]$ at frequency
%
% $$\omega_k = \frac{2\pi}{N} k$$

% %% [markdown]
% ## DFT and Circular Shift
%
% $$ x[(n-m)_N] \leftrightarrow e^{-j\frac{2\pi}{N}km}X[k] $$
%
% - no amplitude changed
% - phase changed

% %% [markdown]
% ## DFT and Modulation
%
% $$ e^{-j\frac{2\pi}{N}r ~n}x[n] \leftrightarrow   X[(k-r)_N] $$

% %% [markdown]
% ## DFT and Circular Convolution
%
% - Circular convolution in the time domain $=$ multiplication in the frequency domain
%
% $$ Y[k] = H[k]X[k] \\
% h[n]\star x[n] \leftrightarrow H[k]X[k] \\
% y[n] = \text{IDFT}(Y[k])$$

% %%
%plot -s 560,420

N = 16;
h = zeros(1,N);
h(1:8) = 1;
n = 0:N-1;
k = n;

X = dft(h,N);

subplot(2,1,1), stem(n,h,'filled'), xlabel('n'), ylabel('x[n]')
subplot(2,1,2), stem(k,abs(X),'filled'), xlabel('freq in k'), ylabel('X[k]')

% %%
kr = [0:N/2-1 -N/2:-1];
ks = fftshift(kr);

Xs = fftshift(X);

subplot(2,1,1), stem(k,abs(X),'filled'), xlabel('freq in k'), ylabel('X[k]')
subplot(2,1,2), stem(ks,abs(Xs),'filled'), xlabel('freq in k'), ylabel('X[k]'), xlim([-N/2,N/2-1])

% %% [markdown]
% $$ e^{-j\frac{2\pi}{N}r ~n}x[n] \leftrightarrow   X[(k-r)_N] $$

% %%
%plot -s 560,600

N = 16;
h = zeros(1,N);
h(1:8) = 1;

for i = 1:N
    h(i) = (-1)^i*h(i);
end

n = 0:N-1;
k = n;

X = dft(h,N);

kr = [0:N/2-1 -N/2:-1];
ks = fftshift(kr);

Xs = fftshift(X);

subplot(3,1,1), stem(n,h,'filled'), xlabel('n'), ylabel('x[n]')
subplot(3,1,2), stem(k,abs(X),'filled'), xlabel('freq in k'), ylabel('X[k]')
subplot(3,1,3), stem(ks,abs(Xs),'filled'), xlabel('freq in k'), ylabel('X[k]'), xlim([-N/2,N/2-1])

% %%
%plot -s 560,420

N = 16;
h = zeros(1,N);
h(1) = 1;
h(2) = -1;
n = 0:N-1;
k = n;

X = dft(h,N);

figure(1)
subplot(2,1,1), stem(n,h,'filled'), xlabel('n'), ylabel('x[n]')
subplot(2,1,2), stem(k,abs(X),'filled'), xlabel('freq in k'), ylabel('X[k]')

% %%
kr = [0:N/2-1 -N/2:-1];
ks = fftshift(kr);

Xs = fftshift(X);

subplot(2,1,1), stem(k,abs(X),'filled'), xlabel('freq in k'), ylabel('X[k]')
subplot(2,1,2), stem(ks,abs(Xs),'filled'), xlabel('freq in k'), ylabel('X[k]'), xlim([-N/2,N/2])

% %%
%plot -s 560,600

N = 16;
h = zeros(1,N);
h(1) = 1;
h(2) = 0;
h(3) = -1;
n = 0:N-1;
k = n;

X = dft(h,N);

kr = [0:N/2-1 -N/2:-1];
ks = fftshift(kr);

Xs = fftshift(X);

subplot(3,1,1), stem(n,h,'filled'), xlabel('n'), ylabel('x[n]')
subplot(3,1,2), stem(k,abs(X),'filled'), xlabel('freq in k'), ylabel('X[k]')
subplot(3,1,3), stem(ks,abs(Xs),'filled'), xlabel('freq in k'), ylabel('X[k]'), xlim([-N/2,N/2-1])

% %% [markdown]
% # Filtering in Frequency Domain

% %%
%plot -s 800,600

%---EXAMPLE 2
%---Denoising a piecewise smooth signal
figure('units','normalized','position',[0 0 1 1.5]);

% piecewise smooth signal
N = 50;
n = 0:N-1;
s = hamming(N) .* [ones(N/2,1); -ones(N/2,1)];

subplot(221)
stem(s,'b','Marker','none','LineWidth',1);
axis([1 N -1.5 1.5])
title('piecewise smooth signal','fontsize',8)

% add noise to the signal
x = s + 0.2*randn(N,1);

subplot(222)
stem(x,'b','Marker','none','LineWidth',1);
axis([1 N -1.5 1.5])
title('piecewise smooth signal + noise','fontsize',8)

% construct moving average filter impulse response of length M
M = 10;
%M = 3;
h = ones(M,1)/M;

h1 = h; h1(N) = 0;
subplot(224)
stem(h1,'b','Marker','none','LineWidth',1);
axis([1 N 0 0.2])
title('impulse response','fontsize',8)

% convolve noisy signal with impulse response
y = circonvt(x',h',50);

subplot(223)
%stem(y(M/2:N+M/2-1),'b','Marker','none','LineWidth',1);
stem(y,'b','Marker','none','LineWidth',1);
axis([1 N -1.5 1.5])
title('output','fontsize',8)

% %%
%plot -s 800,400
H = fft(h,N);
k = n;
figure
stem(k,abs(H))

X = fft(x);

Y = H.*X;
yi = ifft(Y);

subplot(2,1,1), stem(n,(yi),'marker','none')
subplot(2,1,2), 
%stem(y(M/2:N+M/2-1),'b','Marker','none','LineWidth',1);
stem(y,'b','Marker','none','LineWidth',1);
% axis([1 N -1.5 1.5])
title('output','fontsize',8)

% %% [markdown]
% ```octave
% function [Xk] = dft(xn,N)
%
% % Computes Discrete Fourier Transform
% % [Xk] = dft(xn,N)
% % Xk = DFT coeff. array over 0 <= k <= N-1
% % xn = N-point finite-duration sequence
% %  N = Length of DFT
% %
%
% n = [0:1:N-1];                       % row vector for n
% k = [0:1:N-1];                       % row vecor for k
% WN = exp(-1j*2*pi/N);                % Wn factor
% nk = n'*k;                           % creates a N by N matrix of nk values
% WNnk = WN.^nk;                     % DFT matrix
% Xk = xn*WNnk;                      % row vector for DFT coefficients
% ```

% %%
%%javascript
$.getScript('https://kmahelona.github.io/ipython_notebook_goodies/ipython_notebook_toc.js')
